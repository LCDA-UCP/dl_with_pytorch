# %% [markdown]
# # IMDB 50K Movie Reviews - Sentiment Classification with MLP
#
# ## Overview
#
# ### In the next exercises, you will work with the IMDB 50K Movie Reviews dataset to build a sentiment analysis model using a Multi-Layer Perceptron (MLP). You will practice essential steps in the data science pipeline such as data loading, preprocessing, feature generation, and training/testing a neural network model. This exercise should be completed using the `pandas`, `nltk`, `sklearn`, and `torch` libraries.

# %% [markdown]
# ### Exercise 1: Data Loading and Exploration
# **Objective**: Load the IMDB dataset and explore its structure.
#
# 1. **Load the dataset** using `pandas`. The dataset is in the `data/` folder and the file name is `imdb_dataset.zip`. **Hint: you can load zip files with pandas by passing `compression='zip'` tp `pd.read_csv`**
# 2. **Explore the dataset** by checking for missing values and getting a summary of the data.
#     - Check the shape of the dataset.
#     - Get the distribution of the sentiment labels (positive/negative reviews).
# 3. Print the first few reviews and their corresponding labels.

# %%
import modin.pandas as pd

df = pd.read_csv('../../data/imdb_dataset.zip', compression='zip')
df
# Out:
# 2024-10-04 10:00:53,692	INFO worker.py:1786 -- Started a local Ray instance.
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.shape
# Out:
# (50000, 2)

# %%
df['sentiment'].value_counts()
# Out:
# UserWarning: `df.groupby(categorical_by, sort=False)` implementation has mismatches with pandas:
# the groupby keys will be sorted anyway, although the 'sort=False' was passed. See the following issue for more details: https://github.com/modin-project/modin/issues/3571.
# sentiment
# negative    25000
# positive    25000
# Name: count, dtype: int64

# %% [markdown]
# ### Exercise 2: Splitting the Data
# **Objective**: Split the data into training, validation and test sets.
#
# 1. Split the dataset into features (reviews) and labels (sentiment).
# 2. Use `train_test_split` from `sklearn` to split the dataset into training, validation and test sets (use an 60/20/20 split).
# 3. Print the sizes of the training and test sets to ensure the splits were done correctly.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2, stratify=df['sentiment'])
train.shape, test.shape
# Out:
# ((40000, 2), (10000, 2))

# %%
train, valid =train_test_split(train, test_size=0.25, stratify=train['sentiment'])

train.shape, valid.shape, test.shape
# Out:
# ((30000, 2), (10000, 2), (10000, 2))

# %% [markdown]
# ### Exercise 3: Text Preprocessing
# **Objective**: Preprocess the text data to prepare it for feature generation.
#
# 1. Lowercase the text data. **Hint: python has a built-in string method for this**.
# 2. Remove any URL from the reviews. **Hint: you can use regular expressions for this**.
# 3. Remove non-word and non-whitespace characters (punctuation, special characters, etc.). **Hint: you can use regular expressions for this**.
# 4. Remove digits. **Hint: you can use regular expressions for this**.
# 5. Tokenize the reviews into individual words. **Hint: you can use the `nltk` library for this**.
# 6. Remove stopwords. **Hint: you can use the `nltk` library for this**.
# 7. Perform stemming or lemmatization. **Hint: you can use the `nltk` library for this**.
# 8. Apply the preprocessing steps to both the training, validation and test sets.

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()

def preccess(text:str) -> str:
    text = text.lower()
    link_pattern = r'http\S+|www\S+'
    # re.sub(A, B, C)replace A with B in string C
    text = re.sub(link_pattern, '', text)
    non_alphanumeric_pattern = r'\W'
    text = re.sub(non_alphanumeric_pattern, '', text)
    digits_pattern = r'\d'
    text = re.sub(digits_pattern, '', text)
    tokenize = nltk.word_tokenize(text)
    words = [word for word in tokenize if word not in stopwords.words('english')]
    stems = [stemmer.stem(word) for word in words]
    return " ".join(stems)

x_train, y_train = train['review'], train['sentiment']
x_valid, y_valid = valid['review'], valid['sentiment']
x_test, y_test = test['review'], test['sentiment']
# Out:
# [nltk_data] Downloading package stopwords to /home/lcda/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lcda/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
x_train = x_train.apply(preccess)
x_valid = x_valid.apply(preccess)
x_test = x_test.apply(preccess)

x_test
# Out:
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832) **********************************************************************
# (_remote_exec_multi_chain pid=12832)   Resource punkt_tab not found.
# (_remote_exec_multi_chain pid=12832)   Please use the NLTK Downloader to obtain the resource:
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   >>> import nltk
# (_remote_exec_multi_chain pid=12832)   >>> nltk.download('punkt_tab')
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   For more information see: https://www.nltk.org/data.html
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   Attempted to load tokenizers/punkt_tab/english/
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   Searched in:
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/miniconda3/envs/dl_with_pytorch/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/miniconda3/envs/dl_with_pytorch/share/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/miniconda3/envs/dl_with_pytorch/lib/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/share/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/local/share/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/lib/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/local/lib/nltk_data'
# (_remote_exec_multi_chain pid=12832) **********************************************************************
# (_remote_exec_multi_chain pid=12832) . fn=<function Map.register.<locals>.caller.<locals>.<lambda> at 0x75f7ae1b7760>, obj=                                                  review
# (_remote_exec_multi_chain pid=12832) 15061  This opens with the company credits informing ...
# (_remote_exec_multi_chain pid=12832) 47348  Okay. To enjoy this silent comedy short you MU...
# (_remote_exec_multi_chain pid=12832) 37881  Sometimes the Academy doesn't recognize the po...
# (_remote_exec_multi_chain pid=12832) 44674  With this film, Bunuel manipulates the viewer ...
# (_remote_exec_multi_chain pid=12832) 13219  Two dysfunctional brothers (Philip Seymour Hof...
# (_remote_exec_multi_chain pid=12832) ...                                                  ...
# (_remote_exec_multi_chain pid=12832) 43297  Take your video camera, turn out all the light...
# (_remote_exec_multi_chain pid=12832) 44755  This made for TV film is about every cliché yo...
# (_remote_exec_multi_chain pid=12832) 46593  With some wine, some friends and some good hum...
# (_remote_exec_multi_chain pid=12832) 44340  First of all, let me comment that the audience...
# (_remote_exec_multi_chain pid=12832) 47219  A big surprise, probably because I was expecti...
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832) [1072 rows x 1 columns], args=[], kwargs={}
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832) **********************************************************************
# (_remote_exec_multi_chain pid=12832)   Resource punkt_tab not found.
# (_remote_exec_multi_chain pid=12832)   Please use the NLTK Downloader to obtain the resource:
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   >>> import nltk
# (_remote_exec_multi_chain pid=12832)   >>> nltk.download('punkt_tab')
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   For more information see: https://www.nltk.org/data.html
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   Attempted to load tokenizers/punkt_tab/english/
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832)   Searched in:
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/miniconda3/envs/dl_with_pytorch/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/miniconda3/envs/dl_with_pytorch/share/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/home/lcda/miniconda3/envs/dl_with_pytorch/lib/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/share/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/local/share/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/lib/nltk_data'
# (_remote_exec_multi_chain pid=12832)     - '/usr/local/lib/nltk_data'
# (_remote_exec_multi_chain pid=12832) **********************************************************************
# (_remote_exec_multi_chain pid=12832) . args=(                                                  review sentiment
# (_remote_exec_multi_chain pid=12832) 15061  This opens with the company credits informing ...  negative
# (_remote_exec_multi_chain pid=12832) 47348  Okay. To enjoy this silent comedy short you MU...  positive
# (_remote_exec_multi_chain pid=12832) 37881  Sometimes the Academy doesn't recognize the po...  positive
# (_remote_exec_multi_chain pid=12832) 44674  With this film, Bunuel manipulates the viewer ...  negative
# (_remote_exec_multi_chain pid=12832) 13219  Two dysfunctional brothers (Philip Seymour Hof...  positive
# (_remote_exec_multi_chain pid=12832) ...                                                  ...       ...
# (_remote_exec_multi_chain pid=12832) 43297  Take your video camera, turn out all the light...  negative
# (_remote_exec_multi_chain pid=12832) 44755  This made for TV film is about every cliché yo...  negative
# (_remote_exec_multi_chain pid=12832) 46593  With some wine, some friends and some good hum...  positive
# (_remote_exec_multi_chain pid=12832) 44340  First of all, let me comment that the audience...  positive
# (_remote_exec_multi_chain pid=12832) 47219  A big surprise, probably because I was expecti...  positive
# (_remote_exec_multi_chain pid=12832)
# (_remote_exec_multi_chain pid=12832) [1072 rows x 2 columns], <function PandasDataframePartition._iloc at 0x75f7ae1ecf70>, 2, slice(None, None, None), array([0]), 0, 0, 1, <function Map.register.<locals>.caller.<locals>.<lambda> at 0x75f7ae1b7760>, 0, 0, 0, 1), chain=[0, 1]
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813) 39911  Just Cause is one of those films that at first...
# (_remote_exec_multi_chain pid=12813) 48043  Comparing Oceans Twelve to the 2001 Oceans Ele...
# (_remote_exec_multi_chain pid=12813) 30912  To call a movie like "Thinner" bad is like cal...
# (_remote_exec_multi_chain pid=12813) 35537  Extremely boring..I don't care how many avant-...
# (_remote_exec_multi_chain pid=12813) 21812  I love this movie and all aspects of it, well ...
# (_remote_exec_multi_chain pid=12813) 19570  For many years I thought I was the only person...
# (_remote_exec_multi_chain pid=12813) 18665  I'M BOUT IT(1997)<br /><br />Developed & publi...
# (_remote_exec_multi_chain pid=12813) 36351  Can you people please stop believing everythin...
# (_remote_exec_multi_chain pid=12813) 36616  When I watched this movie when I was a kid I d...
# (_remote_exec_multi_chain pid=12813) 23023  A friend of mine gave me this movie. A friend ...
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 12526  Superb story of a dedicated young teacher who ...
# (_remote_exec_multi_chain pid=12820) 18471  We can start with the wooden acting but this f...
# (_remote_exec_multi_chain pid=12820) 14819  I haven't actually seen a lot of movies with H...
# (_remote_exec_multi_chain pid=12820) 33555  Ever notice how so many really bad films attra...
# (_remote_exec_multi_chain pid=12820) 29155  After working on 7 movies with director Mickae...
# (_remote_exec_multi_chain pid=12820) 46133  There are people out there who will greenlight...
# (_remote_exec_multi_chain pid=12820) 42518  For those of you out there who have seen this ...
# (_remote_exec_multi_chain pid=12820) 38716  Those who dislike this film seem to think that...
# (_remote_exec_multi_chain pid=12820) 34572  The premise for this movie is simple and so is...
# (_remote_exec_multi_chain pid=12820) 5925   To be fair, I didn't see a lot of this show. P...
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816) 25087  Wow! I truly regret watching this picture... F...
# (_remote_exec_multi_chain pid=12816) 15400  Since I am so interested in lake monsters i re...
# (_remote_exec_multi_chain pid=12816) 25917  The Movie is okay. Meaning that I don't regret...
# (_remote_exec_multi_chain pid=12816) 35617  Up front, if you're tired, the first hour coul...
# (_remote_exec_multi_chain pid=12816) 20149  Well, how to start? I saw The Italian Job for ...
# (_remote_exec_multi_chain pid=12816) 27400  George Sanders playing the Saint for the penul...
# (_remote_exec_multi_chain pid=12816) 9958   I am a big fan of "Auntie Mame" with Rosalind ...
# (_remote_exec_multi_chain pid=12816) 15211  I saw this short film on the dvd for Ridley Sc...
# (_remote_exec_multi_chain pid=12816) 16049  gone in 60 seconds is a very good action comed...
# (_remote_exec_multi_chain pid=12816) 2735   This movie has everything going for it: Fully ...
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812) 16251  These two stars are the only iconic heroes/vil...
# (_remote_exec_multi_chain pid=12812) 47115  This film differentiates itself from the run-o...
# (_remote_exec_multi_chain pid=12812) 23762  When I saw this movie I think I was a freshman...
# (_remote_exec_multi_chain pid=12812) 16961  I was lucky enough to get a DVD copy of this m...
# (_remote_exec_multi_chain pid=12812) 293    Focus is another great movie starring William ...
# (_remote_exec_multi_chain pid=12812) 8847   Very good 1939 film where John Garfield plays ...
# (_remote_exec_multi_chain pid=12812) 19855  this is the best sci-fi that I have seen in my...
# (_remote_exec_multi_chain pid=12812) 12195  In the first 20 minutes, every cliche possible...
# (_remote_exec_multi_chain pid=12812) 7358   I haven't seen this film since it came out in ...
# (_remote_exec_multi_chain pid=12812) 23636  It's been a long time since such an original, ...
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12813) 39911  Just Cause is one of those films that at first...  negative
# (_remote_exec_multi_chain pid=12813) 48043  Comparing Oceans Twelve to the 2001 Oceans Ele...  negative
# (_remote_exec_multi_chain pid=12813) 30912  To call a movie like "Thinner" bad is like cal...  negative
# (_remote_exec_multi_chain pid=12813) 35537  Extremely boring..I don't care how many avant-...  negative
# (_remote_exec_multi_chain pid=12813) 21812  I love this movie and all aspects of it, well ...  positive
# (_remote_exec_multi_chain pid=12813) 19570  For many years I thought I was the only person...  positive
# (_remote_exec_multi_chain pid=12813) 18665  I'M BOUT IT(1997)<br /><br />Developed & publi...  negative
# (_remote_exec_multi_chain pid=12813) 36351  Can you people please stop believing everythin...  negative
# (_remote_exec_multi_chain pid=12813) 36616  When I watched this movie when I was a kid I d...  positive
# (_remote_exec_multi_chain pid=12813) 23023  A friend of mine gave me this movie. A friend ...  negative
# (_remote_exec_multi_chain pid=12813)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 12526  Superb story of a dedicated young teacher who ...  positive
# (_remote_exec_multi_chain pid=12820) 18471  We can start with the wooden acting but this f...  negative
# (_remote_exec_multi_chain pid=12820) 14819  I haven't actually seen a lot of movies with H...  positive
# (_remote_exec_multi_chain pid=12820) 33555  Ever notice how so many really bad films attra...  negative
# (_remote_exec_multi_chain pid=12820) 29155  After working on 7 movies with director Mickae...  positive
# (_remote_exec_multi_chain pid=12820) 46133  There are people out there who will greenlight...  negative
# (_remote_exec_multi_chain pid=12820) 42518  For those of you out there who have seen this ...  positive
# (_remote_exec_multi_chain pid=12820) 38716  Those who dislike this film seem to think that...  positive
# (_remote_exec_multi_chain pid=12820) 34572  The premise for this movie is simple and so is...  positive
# (_remote_exec_multi_chain pid=12820) 5925   To be fair, I didn't see a lot of this show. P...  negative
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12816) 25087  Wow! I truly regret watching this picture... F...  negative
# (_remote_exec_multi_chain pid=12816) 15400  Since I am so interested in lake monsters i re...  positive
# (_remote_exec_multi_chain pid=12816) 25917  The Movie is okay. Meaning that I don't regret...  negative
# (_remote_exec_multi_chain pid=12816) 35617  Up front, if you're tired, the first hour coul...  positive
# (_remote_exec_multi_chain pid=12816) 20149  Well, how to start? I saw The Italian Job for ...  negative
# (_remote_exec_multi_chain pid=12816) 27400  George Sanders playing the Saint for the penul...  positive
# (_remote_exec_multi_chain pid=12816) 9958   I am a big fan of "Auntie Mame" with Rosalind ...  negative
# (_remote_exec_multi_chain pid=12816) 15211  I saw this short film on the dvd for Ridley Sc...  negative
# (_remote_exec_multi_chain pid=12816) 16049  gone in 60 seconds is a very good action comed...  positive
# (_remote_exec_multi_chain pid=12816) 2735   This movie has everything going for it: Fully ...  positive
# (_remote_exec_multi_chain pid=12816)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_multi_chain pid=12812) 16251  These two stars are the only iconic heroes/vil...  positive
# (_remote_exec_multi_chain pid=12812) 47115  This film differentiates itself from the run-o...  negative
# (_remote_exec_multi_chain pid=12812) 23762  When I saw this movie I think I was a freshman...  negative
# (_remote_exec_multi_chain pid=12812) 16961  I was lucky enough to get a DVD copy of this m...  positive
# (_remote_exec_multi_chain pid=12812) 293    Focus is another great movie starring William ...  positive
# (_remote_exec_multi_chain pid=12812) 8847   Very good 1939 film where John Garfield plays ...  positive
# (_remote_exec_multi_chain pid=12812) 19855  this is the best sci-fi that I have seen in my...  positive
# (_remote_exec_multi_chain pid=12812) 12195  In the first 20 minutes, every cliche possible...  negative
# (_remote_exec_multi_chain pid=12812) 7358   I haven't seen this film since it came out in ...  positive
# (_remote_exec_multi_chain pid=12812) 23636  It's been a long time since such an original, ...  positive
# (_remote_exec_multi_chain pid=12812)
# (_remote_exec_single_chain pid=12832)
# (_remote_exec_single_chain pid=12832)
# (_remote_exec_single_chain pid=12832)
# (_remote_exec_single_chain pid=12832)
# (_remote_exec_single_chain pid=12832)
# (_remote_exec_single_chain pid=12832) 19314  My only question is: Why did they make this mo...
# (_remote_exec_single_chain pid=12832) 7048   I LOVE Dr WHo SO much! I believe that David Te...
# (_remote_exec_single_chain pid=12832) 21053  My wife and I watched this marvelous movie thi...
# (_remote_exec_single_chain pid=12832) 6690   Billy and Jade had a very close relationship t...
# (_remote_exec_single_chain pid=12832) 18187  The Sea Is Watching has been made from an orig...
# (_remote_exec_single_chain pid=12832) 1798   "Laugh, Clown Laugh" released in 1928, stars t...
# (_remote_exec_single_chain pid=12832) 22851  Eros and Thanatos, Love and Death command the ...
# (_remote_exec_single_chain pid=12832) 1479   I first heard about The Melancholy of Haruhi S...
# (_remote_exec_single_chain pid=12832) 32436  If the themes of The Girl From Missouri sound ...
# (_remote_exec_single_chain pid=12832) 328    The sexploitation movie era of the late sixtie...
# (_remote_exec_single_chain pid=12832)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811) 41156  Fantastic documentary. A movie within a movie....
# (_remote_exec_multi_chain pid=12811) 30638  ***SPOILERS*** ***SPOILERS*** Well, seeing as ...
# (_remote_exec_multi_chain pid=12811) 5090   Halfway through Lajos Koltai's "Evening," a wo...
# (_remote_exec_multi_chain pid=12811) 42471  May contain spoilers.<br /><br />I say that, b...
# (_remote_exec_multi_chain pid=12811) 22499  Sherlock Holmes (Basil Rathbone) and Professor...
# (_remote_exec_multi_chain pid=12811) 33501  This movie was a mess. It had the absolute wor...
# (_remote_exec_multi_chain pid=12811) 23084  I saw a version of this in a 4 DVD Mafia colle...
# (_remote_exec_multi_chain pid=12811) 13193  I've felt that Rupert Grint has a lot of promi...
# (_remote_exec_multi_chain pid=12811) 5998   Annie's wig does not look good. she is not cut...
# (_remote_exec_multi_chain pid=12811) 146    A family is traveling through the mid West. Th...
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12811) 41156  Fantastic documentary. A movie within a movie....  positive
# (_remote_exec_multi_chain pid=12811) 30638  ***SPOILERS*** ***SPOILERS*** Well, seeing as ...  positive
# (_remote_exec_multi_chain pid=12811) 5090   Halfway through Lajos Koltai's "Evening," a wo...  positive
# (_remote_exec_multi_chain pid=12811) 42471  May contain spoilers.<br /><br />I say that, b...  negative
# (_remote_exec_multi_chain pid=12811) 22499  Sherlock Holmes (Basil Rathbone) and Professor...  positive
# (_remote_exec_multi_chain pid=12811) 33501  This movie was a mess. It had the absolute wor...  negative
# (_remote_exec_multi_chain pid=12811) 23084  I saw a version of this in a 4 DVD Mafia colle...  positive
# (_remote_exec_multi_chain pid=12811) 13193  I've felt that Rupert Grint has a lot of promi...  positive
# (_remote_exec_multi_chain pid=12811) 5998   Annie's wig does not look good. she is not cut...  negative
# (_remote_exec_multi_chain pid=12811) 146    A family is traveling through the mid West. Th...  positive
# (_remote_exec_multi_chain pid=12811)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827) 29204  Lord Alan Cunningham(Antonio De Teffè)is a nut...
# (_remote_exec_multi_chain pid=12827) 21838  honestly, if anyone has a brain, there's not 1...
# (_remote_exec_multi_chain pid=12827) 25555  The humor in Who's Your Daddy is such poor tas...
# (_remote_exec_multi_chain pid=12827) 22845  Wow this really is stereotypical, terrible tra...
# (_remote_exec_multi_chain pid=12827) 912    SHALLOW GRAVE begins with either a tribute or ...
# (_remote_exec_multi_chain pid=12827) 40277  In a word, this film was boring. It lacked lif...
# (_remote_exec_multi_chain pid=12827) 32877  For those who commented on The Patriot as bein...
# (_remote_exec_multi_chain pid=12827) 8681   Its my favourite film because there's so much ...
# (_remote_exec_multi_chain pid=12827) 26645  The main character Lance Barton gets killed an...
# (_remote_exec_multi_chain pid=12827) 26923  After seeing a preview for this film at my loc...
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827) 29204  Lord Alan Cunningham(Antonio De Teffè)is a nut...  negative
# (_remote_exec_multi_chain pid=12827) 21838  honestly, if anyone has a brain, there's not 1...  negative
# (_remote_exec_multi_chain pid=12827) 25555  The humor in Who's Your Daddy is such poor tas...  negative
# (_remote_exec_multi_chain pid=12827) 22845  Wow this really is stereotypical, terrible tra...  negative
# (_remote_exec_multi_chain pid=12827) 912    SHALLOW GRAVE begins with either a tribute or ...  negative
# (_remote_exec_multi_chain pid=12827) 40277  In a word, this film was boring. It lacked lif...  negative
# (_remote_exec_multi_chain pid=12827) 32877  For those who commented on The Patriot as bein...  positive
# (_remote_exec_multi_chain pid=12827) 8681   Its my favourite film because there's so much ...  positive
# (_remote_exec_multi_chain pid=12827) 26645  The main character Lance Barton gets killed an...  negative
# (_remote_exec_multi_chain pid=12827) 26923  After seeing a preview for this film at my loc...  positive
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827) 31395  Bedrooms and Hallways gives its audience a loo...
# (_remote_exec_multi_chain pid=12827) 48676  I think that if I went to a first school somew...
# (_remote_exec_multi_chain pid=12827) 2130   Seeing as the world snooker championship final...
# (_remote_exec_multi_chain pid=12827) 49579  If you watched the series and love the league ...
# (_remote_exec_multi_chain pid=12827) 37115  Chaplin stars in a dual role as a jewish barbe...
# (_remote_exec_multi_chain pid=12827) 46943  I saw this "hot" movie when it came out in 198...
# (_remote_exec_multi_chain pid=12827) 36831  Saxophonist Ronnie Bowers (Dick Powell) wins a...
# (_remote_exec_multi_chain pid=12827) 49456  I loved so much about this movie...the time ta...
# (_remote_exec_multi_chain pid=12827) 4473   Through the years I've been very much interest...
# (_remote_exec_multi_chain pid=12827) 31266  Gerald McRaney,(Dave Morgan),"War Crimes",'01 ...
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12827) 31395  Bedrooms and Hallways gives its audience a loo...  positive
# (_remote_exec_multi_chain pid=12827) 48676  I think that if I went to a first school somew...  negative
# (_remote_exec_multi_chain pid=12827) 2130   Seeing as the world snooker championship final...  negative
# (_remote_exec_multi_chain pid=12827) 49579  If you watched the series and love the league ...  negative
# (_remote_exec_multi_chain pid=12827) 37115  Chaplin stars in a dual role as a jewish barbe...  positive
# (_remote_exec_multi_chain pid=12827) 46943  I saw this "hot" movie when it came out in 198...  negative
# (_remote_exec_multi_chain pid=12827) 36831  Saxophonist Ronnie Bowers (Dick Powell) wins a...  positive
# (_remote_exec_multi_chain pid=12827) 49456  I loved so much about this movie...the time ta...  positive
# (_remote_exec_multi_chain pid=12827) 4473   Through the years I've been very much interest...  positive
# (_remote_exec_multi_chain pid=12827) 31266  Gerald McRaney,(Dave Morgan),"War Crimes",'01 ...  positive
# (_remote_exec_multi_chain pid=12827)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830) 7137   There are some redeeming qualities to this sho...
# (_remote_exec_multi_chain pid=12830) 20450  Similar story line, done many times before, an...
# (_remote_exec_multi_chain pid=12830) 9411   After all these years of solving crimes, you w...
# (_remote_exec_multi_chain pid=12830) 37930  I only wish there was a grade lower than F to ...
# (_remote_exec_multi_chain pid=12830) 35981  Having previously seen this short on VHS tape ...
# (_remote_exec_multi_chain pid=12830) 1877   i had no idea what this movies was about, it j...
# (_remote_exec_multi_chain pid=12830) 14268  This movie stunk. There is not much more to it...
# (_remote_exec_multi_chain pid=12830) 5334   I really seldom give either one or ten stars t...
# (_remote_exec_multi_chain pid=12830) 10973  This is a terrible movie, don't waste your mon...
# (_remote_exec_multi_chain pid=12830) 44895  I suppose it's nice and trendy to see wonderfu...
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830) 7137   There are some redeeming qualities to this sho...  negative
# (_remote_exec_multi_chain pid=12830) 20450  Similar story line, done many times before, an...  negative
# (_remote_exec_multi_chain pid=12830) 9411   After all these years of solving crimes, you w...  positive
# (_remote_exec_multi_chain pid=12830) 37930  I only wish there was a grade lower than F to ...  negative
# (_remote_exec_multi_chain pid=12830) 35981  Having previously seen this short on VHS tape ...  positive
# (_remote_exec_multi_chain pid=12830) 1877   i had no idea what this movies was about, it j...  negative
# (_remote_exec_multi_chain pid=12830) 14268  This movie stunk. There is not much more to it...  negative
# (_remote_exec_multi_chain pid=12830) 5334   I really seldom give either one or ten stars t...  negative
# (_remote_exec_multi_chain pid=12830) 10973  This is a terrible movie, don't waste your mon...  negative
# (_remote_exec_multi_chain pid=12830) 44895  I suppose it's nice and trendy to see wonderfu...  negative
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830) 24411  That this film flopped at the box office, and ...
# (_remote_exec_multi_chain pid=12830) 48664  What a waste of precious time! My 5-year-old d...
# (_remote_exec_multi_chain pid=12830) 4103   The film starts with a manager (Nicholas Bell)...
# (_remote_exec_multi_chain pid=12830) 5491   The murder of the Red Comyn in Grayfriars Abbe...
# (_remote_exec_multi_chain pid=12830) 41324  This was one of those films I would always com...
# (_remote_exec_multi_chain pid=12830) 13552  Los Angeles physician Tom Reed (Vincent Ventre...
# (_remote_exec_multi_chain pid=12830) 15646  I recently bought the DVD, forgetting just how...
# (_remote_exec_multi_chain pid=12830) 10599  Yet another insult and slap in the face to gay...
# (_remote_exec_multi_chain pid=12830) 42087  This show was laughably bad. The writing sucke...
# (_remote_exec_multi_chain pid=12830) 38504  Robert A. Heinlein's classic novel Starship Tr...
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12830) 24411  That this film flopped at the box office, and ...  positive
# (_remote_exec_multi_chain pid=12830) 48664  What a waste of precious time! My 5-year-old d...  negative
# (_remote_exec_multi_chain pid=12830) 4103   The film starts with a manager (Nicholas Bell)...  negative
# (_remote_exec_multi_chain pid=12830) 5491   The murder of the Red Comyn in Grayfriars Abbe...  negative
# (_remote_exec_multi_chain pid=12830) 41324  This was one of those films I would always com...  positive
# (_remote_exec_multi_chain pid=12830) 13552  Los Angeles physician Tom Reed (Vincent Ventre...  negative
# (_remote_exec_multi_chain pid=12830) 15646  I recently bought the DVD, forgetting just how...  negative
# (_remote_exec_multi_chain pid=12830) 10599  Yet another insult and slap in the face to gay...  negative
# (_remote_exec_multi_chain pid=12830) 42087  This show was laughably bad. The writing sucke...  negative
# (_remote_exec_multi_chain pid=12830) 38504  Robert A. Heinlein's classic novel Starship Tr...  positive
# (_remote_exec_multi_chain pid=12830)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 37833  When Family Guy first premiered, I was not in ...
# (_remote_exec_multi_chain pid=12829) 6818   In one of the better movies of the year, Tom H...
# (_remote_exec_multi_chain pid=12829) 30990  i should qualify that title, now that i think ...
# (_remote_exec_multi_chain pid=12829) 29313  I mean really, really, REALLY high and this mo...
# (_remote_exec_multi_chain pid=12829) 34503  For many years, Samuel Goldwin tried to bring ...
# (_remote_exec_multi_chain pid=12829) 19608  Though this movie has a first rate roster of f...
# (_remote_exec_multi_chain pid=12829) 27764  This is a rip off of the old Frankenstein prem...
# (_remote_exec_multi_chain pid=12829) 49328  Michael Ritchie's "The Couch Trip" is a wonder...
# (_remote_exec_multi_chain pid=12829) 12006  Slaughter Trail is a B western with some grand...
# (_remote_exec_multi_chain pid=12829) 44227  the Germans all stand out in the open and get ...
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 37833  When Family Guy first premiered, I was not in ...  negative
# (_remote_exec_multi_chain pid=12829) 6818   In one of the better movies of the year, Tom H...  positive
# (_remote_exec_multi_chain pid=12829) 30990  i should qualify that title, now that i think ...  negative
# (_remote_exec_multi_chain pid=12829) 29313  I mean really, really, REALLY high and this mo...  negative
# (_remote_exec_multi_chain pid=12829) 34503  For many years, Samuel Goldwin tried to bring ...  positive
# (_remote_exec_multi_chain pid=12829) 19608  Though this movie has a first rate roster of f...  positive
# (_remote_exec_multi_chain pid=12829) 27764  This is a rip off of the old Frankenstein prem...  negative
# (_remote_exec_multi_chain pid=12829) 49328  Michael Ritchie's "The Couch Trip" is a wonder...  positive
# (_remote_exec_multi_chain pid=12829) 12006  Slaughter Trail is a B western with some grand...  negative
# (_remote_exec_multi_chain pid=12829) 44227  the Germans all stand out in the open and get ...  negative
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 25688  I mostly rented this movie to see Shannon Eliz...
# (_remote_exec_multi_chain pid=12829) 4753   The school nerd Marty (Simon Scuddamore) is se...
# (_remote_exec_multi_chain pid=12829) 42527  I watched this as part of a vampire movie mara...
# (_remote_exec_multi_chain pid=12829) 21357  "Catchfire" or "Backtrack" as it is sometimes ...
# (_remote_exec_multi_chain pid=12829) 22727  ..but unfortunately no one thought about havin...
# (_remote_exec_multi_chain pid=12829) 48342  Some 25 year olds behave like teenagers, copin...
# (_remote_exec_multi_chain pid=12829) 49641  Astounding that something like this could find...
# (_remote_exec_multi_chain pid=12829) 34507  Since I first saw Anchors Aweigh in 1945, view...
# (_remote_exec_multi_chain pid=12829) 35093  Hitchcock's original classic benefited tremend...
# (_remote_exec_multi_chain pid=12829) 22347  I rented this on DVD yesterday and did not rea...
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 25688  I mostly rented this movie to see Shannon Eliz...  negative
# (_remote_exec_multi_chain pid=12829) 4753   The school nerd Marty (Simon Scuddamore) is se...  negative
# (_remote_exec_multi_chain pid=12829) 42527  I watched this as part of a vampire movie mara...  negative
# (_remote_exec_multi_chain pid=12829) 21357  "Catchfire" or "Backtrack" as it is sometimes ...  negative
# (_remote_exec_multi_chain pid=12829) 22727  ..but unfortunately no one thought about havin...  negative
# (_remote_exec_multi_chain pid=12829) 48342  Some 25 year olds behave like teenagers, copin...  negative
# (_remote_exec_multi_chain pid=12829) 49641  Astounding that something like this could find...  negative
# (_remote_exec_multi_chain pid=12829) 34507  Since I first saw Anchors Aweigh in 1945, view...  positive
# (_remote_exec_multi_chain pid=12829) 35093  Hitchcock's original classic benefited tremend...  negative
# (_remote_exec_multi_chain pid=12829) 22347  I rented this on DVD yesterday and did not rea...  negative
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 40916  Ludicrous violations of the most basic securit...
# (_remote_exec_multi_chain pid=12829) 5731   Upon The Straight Story release in 1999, it wa...
# (_remote_exec_multi_chain pid=12829) 45954  Los Angeles TV news reporter Jennifer (the bea...
# (_remote_exec_multi_chain pid=12829) 15358  German filmmaker Ulli Lommel has managed a tas...
# (_remote_exec_multi_chain pid=12829) 49123  Jennifer Grey seems the unlikeliest of romanti...
# (_remote_exec_multi_chain pid=12829) 38901  I agree with what "veinbreaker" wrote with reg...
# (_remote_exec_multi_chain pid=12829) 29366  This film is probably the worst film that I ha...
# (_remote_exec_multi_chain pid=12829) 7391   This movie gave me recurring nightmares, with ...
# (_remote_exec_multi_chain pid=12829) 33360  I've heard many things about Beowulf, maybe be...
# (_remote_exec_multi_chain pid=12829) 47976  I've seen this programme a few times and the m...
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 40916  Ludicrous violations of the most basic securit...  negative
# (_remote_exec_multi_chain pid=12829) 5731   Upon The Straight Story release in 1999, it wa...  positive
# (_remote_exec_multi_chain pid=12829) 45954  Los Angeles TV news reporter Jennifer (the bea...  positive
# (_remote_exec_multi_chain pid=12829) 15358  German filmmaker Ulli Lommel has managed a tas...  negative
# (_remote_exec_multi_chain pid=12829) 49123  Jennifer Grey seems the unlikeliest of romanti...  positive
# (_remote_exec_multi_chain pid=12829) 38901  I agree with what "veinbreaker" wrote with reg...  positive
# (_remote_exec_multi_chain pid=12829) 29366  This film is probably the worst film that I ha...  negative
# (_remote_exec_multi_chain pid=12829) 7391   This movie gave me recurring nightmares, with ...  positive
# (_remote_exec_multi_chain pid=12829) 33360  I've heard many things about Beowulf, maybe be...  negative
# (_remote_exec_multi_chain pid=12829) 47976  I've seen this programme a few times and the m...  negative
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 39254  Hey! The Grudge 2! What up, man? I have a frie...
# (_remote_exec_multi_chain pid=12829) 6287   I have to be honest, i was expecting a failure...
# (_remote_exec_multi_chain pid=12829) 43984  Skeletons In The Closet takes the father-teena...
# (_remote_exec_multi_chain pid=12829) 37800  Yeah it may not be for adults, and some adults...
# (_remote_exec_multi_chain pid=12829) 43923  This is a woeful Hollywood remake of a classic...
# (_remote_exec_multi_chain pid=12829) 6791   To be honest, I didn't like that much this mov...
# (_remote_exec_multi_chain pid=12829) 45430  Shocking!<br /><br />In 1965 I saw Jury Gagari...
# (_remote_exec_multi_chain pid=12829) 13574  I've noticed that a lot of people who post on ...
# (_remote_exec_multi_chain pid=12829) 21629  Great softcore sex, revealing and sexy, and pl...
# (_remote_exec_multi_chain pid=12829) 18486  This film is outstanding! On this date of APR,...
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12829) 39254  Hey! The Grudge 2! What up, man? I have a frie...  negative
# (_remote_exec_multi_chain pid=12829) 6287   I have to be honest, i was expecting a failure...  positive
# (_remote_exec_multi_chain pid=12829) 43984  Skeletons In The Closet takes the father-teena...  negative
# (_remote_exec_multi_chain pid=12829) 37800  Yeah it may not be for adults, and some adults...  negative
# (_remote_exec_multi_chain pid=12829) 43923  This is a woeful Hollywood remake of a classic...  negative
# (_remote_exec_multi_chain pid=12829) 6791   To be honest, I didn't like that much this mov...  positive
# (_remote_exec_multi_chain pid=12829) 45430  Shocking!<br /><br />In 1965 I saw Jury Gagari...  negative
# (_remote_exec_multi_chain pid=12829) 13574  I've noticed that a lot of people who post on ...  positive
# (_remote_exec_multi_chain pid=12829) 21629  Great softcore sex, revealing and sexy, and pl...  positive
# (_remote_exec_multi_chain pid=12829) 18486  This film is outstanding! On this date of APR,...  positive
# (_remote_exec_multi_chain pid=12829)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 29874  This series was just like what you would expec...
# (_remote_exec_multi_chain pid=12820) 10849  Mas Oyama was the most successful karate maste...
# (_remote_exec_multi_chain pid=12820) 37360  For the first three seasons, Sabrina was a gem...
# (_remote_exec_multi_chain pid=12820) 46695  Jeopardy is a tense, satisying thriller, a cut...
# (_remote_exec_multi_chain pid=12820) 4145   If it were possible to distill the heart and s...
# (_remote_exec_multi_chain pid=12820) 10508  This film has not exactly remained fresh in th...
# (_remote_exec_multi_chain pid=12820) 24241  My friend recommended this movie to me.Is shou...
# (_remote_exec_multi_chain pid=12820) 46352  `Mad Dog' Earle is back, along with his sad-sa...
# (_remote_exec_multi_chain pid=12820) 15788  No, *Hitch* is decidedly NOT a romantic-comedy...
# (_remote_exec_multi_chain pid=12820) 38576  This movie had potential, but what makes it re...
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 29874  This series was just like what you would expec...  positive
# (_remote_exec_multi_chain pid=12820) 10849  Mas Oyama was the most successful karate maste...  positive
# (_remote_exec_multi_chain pid=12820) 37360  For the first three seasons, Sabrina was a gem...  positive
# (_remote_exec_multi_chain pid=12820) 46695  Jeopardy is a tense, satisying thriller, a cut...  positive
# (_remote_exec_multi_chain pid=12820) 4145   If it were possible to distill the heart and s...  positive
# (_remote_exec_multi_chain pid=12820) 10508  This film has not exactly remained fresh in th...  positive
# (_remote_exec_multi_chain pid=12820) 24241  My friend recommended this movie to me.Is shou...  negative
# (_remote_exec_multi_chain pid=12820) 46352  `Mad Dog' Earle is back, along with his sad-sa...  positive
# (_remote_exec_multi_chain pid=12820) 15788  No, *Hitch* is decidedly NOT a romantic-comedy...  negative
# (_remote_exec_multi_chain pid=12820) 38576  This movie had potential, but what makes it re...  negative
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 45826  Well, what can be said about a "horror comedy"...
# (_remote_exec_multi_chain pid=12820) 18513  For those of us who are part of the real world...
# (_remote_exec_multi_chain pid=12820) 25392  The stars and the planets must've all been in ...
# (_remote_exec_multi_chain pid=12820) 28183  I'm too old to know (or care) exactly what the...
# (_remote_exec_multi_chain pid=12820) 3763   For all the hoopla, respect and recognition th...
# (_remote_exec_multi_chain pid=12820) 22201  There is this private campground in Plymouth, ...
# (_remote_exec_multi_chain pid=12820) 47815  Pavarotti and the entire cast are superb in th...
# (_remote_exec_multi_chain pid=12820) 5281   If you've had drama in your life, either your ...
# (_remote_exec_multi_chain pid=12820) 10322  The year is 1896.Jeff Webster (James Stewart) ...
# (_remote_exec_multi_chain pid=12820) 37343  You'd think a movie about incestuous sisters w...
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 45826  Well, what can be said about a "horror comedy"...  negative
# (_remote_exec_multi_chain pid=12820) 18513  For those of us who are part of the real world...  negative
# (_remote_exec_multi_chain pid=12820) 25392  The stars and the planets must've all been in ...  positive
# (_remote_exec_multi_chain pid=12820) 28183  I'm too old to know (or care) exactly what the...  positive
# (_remote_exec_multi_chain pid=12820) 3763   For all the hoopla, respect and recognition th...  positive
# (_remote_exec_multi_chain pid=12820) 22201  There is this private campground in Plymouth, ...  positive
# (_remote_exec_multi_chain pid=12820) 47815  Pavarotti and the entire cast are superb in th...  positive
# (_remote_exec_multi_chain pid=12820) 5281   If you've had drama in your life, either your ...  positive
# (_remote_exec_multi_chain pid=12820) 10322  The year is 1896.Jeff Webster (James Stewart) ...  positive
# (_remote_exec_multi_chain pid=12820) 37343  You'd think a movie about incestuous sisters w...  negative
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 33109  Three kids are born during a solar eclipse and...
# (_remote_exec_multi_chain pid=12820) 42461  I endured this film just to satisfy my curiosi...
# (_remote_exec_multi_chain pid=12820) 48400  This is a very rare film and probably the leas...
# (_remote_exec_multi_chain pid=12820) 38396  I don't know how I would feel if I lived in US...
# (_remote_exec_multi_chain pid=12820) 37506  Tonight's film course film was The Legend of t...
# (_remote_exec_multi_chain pid=12820) 36868  Thank you Hollywood. Yet another movie classic...
# (_remote_exec_multi_chain pid=12820) 43412  How on earth were these guys given funds to ma...
# (_remote_exec_multi_chain pid=12820) 44970  Oh, man! This thing scared the heck out of me ...
# (_remote_exec_multi_chain pid=12820) 41465  From start to finish, this 1926 classic two re...
# (_remote_exec_multi_chain pid=12820) 7730   Leon was fantastic as always, this time playin...
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 33109  Three kids are born during a solar eclipse and...  positive
# (_remote_exec_multi_chain pid=12820) 42461  I endured this film just to satisfy my curiosi...  negative
# (_remote_exec_multi_chain pid=12820) 48400  This is a very rare film and probably the leas...  positive
# (_remote_exec_multi_chain pid=12820) 38396  I don't know how I would feel if I lived in US...  positive
# (_remote_exec_multi_chain pid=12820) 37506  Tonight's film course film was The Legend of t...  negative
# (_remote_exec_multi_chain pid=12820) 36868  Thank you Hollywood. Yet another movie classic...  negative
# (_remote_exec_multi_chain pid=12820) 43412  How on earth were these guys given funds to ma...  negative
# (_remote_exec_multi_chain pid=12820) 44970  Oh, man! This thing scared the heck out of me ...  negative
# (_remote_exec_multi_chain pid=12820) 41465  From start to finish, this 1926 classic two re...  positive
# (_remote_exec_multi_chain pid=12820) 7730   Leon was fantastic as always, this time playin...  positive
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 48238  I do not see what is the whole deal about this...
# (_remote_exec_multi_chain pid=12820) 25681  ****SPOILERS**** The film "Sniper" is undoubte...
# (_remote_exec_multi_chain pid=12820) 43411  In some ways, the concept behind the storyline...
# (_remote_exec_multi_chain pid=12820) 19716  Sure, I like short cartoons, but I didn't like...
# (_remote_exec_multi_chain pid=12820) 28024  Even an old cynical DOCTOR WHO fan like myself...
# (_remote_exec_multi_chain pid=12820) 20950  I'm going to say first off that I have given t...
# (_remote_exec_multi_chain pid=12820) 15198  I remember watching this in the 1970s - then I...
# (_remote_exec_multi_chain pid=12820) 14628  Well what do you know, I was painting my house...
# (_remote_exec_multi_chain pid=12820) 10698  This is one of the most boring films I've ever...
# (_remote_exec_multi_chain pid=12820) 46628  I saw this movie in my international cinema cl...
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820)
# (_remote_exec_multi_chain pid=12820) 48238  I do not see what is the whole deal about this...  negative
# (_remote_exec_multi_chain pid=12820) 25681  ****SPOILERS**** The film "Sniper" is undoubte...  positive
# (_remote_exec_multi_chain pid=12820) 43411  In some ways, the concept behind the storyline...  negative
# ...
# (_remote_exec_multi_chain pid=12834)
# (_remote_exec_multi_chain pid=12834)
# (_remote_exec_multi_chain pid=12834)
# (_remote_exec_multi_chain pid=12834)
# (_remote_exec_multi_chain pid=12834)
# (_remote_exec_multi_chain pid=12834)
# (_remote_exec_multi_chain pid=12834) 34420  Went to Wal-Mart and found this film on DVD an...  positive
# (_remote_exec_multi_chain pid=12834) 18274  This movie was amusing at times, hell sometime...  negative
# (_remote_exec_multi_chain pid=12834) 24612  Dreamy young Ashton Kutcher (as Tom Stansfield...  negative
# (_remote_exec_multi_chain pid=12834) 9381   i adore this film as much as any one adores vi...  positive
# (_remote_exec_multi_chain pid=12834) 29133  When I first saw "Race Against Fear" (don't yo...  negative
# (_remote_exec_multi_chain pid=12834) 28512  The premise may seem goofy, but since Murphy's...  positive
# (_remote_exec_multi_chain pid=12834) 22573  I just bought the DVD and i must say, (after s...  positive
# (_remote_exec_multi_chain pid=12834) 44763  This movie is still alive and kicking today th...  positive
# (_remote_exec_multi_chain pid=12834) 34529  First of all, write the script on a napkin. Wh...  negative
# (_remote_exec_multi_chain pid=12834) 40645  Coming immediately on the heels of Match Point...  positive
# (_remote_exec_multi_chain pid=12834)
# ---------------------------------------------------------------------------
# RayTaskError(LookupError)                 Traceback (most recent call last)
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/IPython/core/formatters.py:711, in PlainTextFormatter.__call__(self, obj)
#     704 stream = StringIO()
#     705 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706     self.max_width, self.newline,
#     707     max_seq_length=self.max_seq_length,
#     708     singleton_pprinters=self.singleton_printers,
#     709     type_pprinters=self.type_printers,
#     710     deferred_pprinters=self.deferred_printers)
# --> 711 printer.pretty(obj)
#     712 printer.flush()
#     713 return stream.getvalue()
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/IPython/lib/pretty.py:419, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
#     409                 if (
#     410                     cls is not object
#     411                     # check if cls defines __repr__
#    (...)
#     417                     and callable(_safe_getattr(cls, "__repr__", None))
#     418                 ):
# --> 419                     return _repr_pprint(obj, self, cycle)
#     421     return _default_pprint(obj, self, cycle)
#     422 finally:
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/IPython/lib/pretty.py:787, in _repr_pprint(obj, p, cycle)
#     785 """A pprint that just redirects to the normal repr function."""
#     786 # Find newlines and replace them with p.break_()
# --> 787 output = repr(obj)
#     788 lines = output.splitlines()
#     789 with p.group():
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/logging/logger_decorator.py:125, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     110 """
#     111 Compute function with logging if Modin logging is enabled.
#     112
#    (...)
#     122 Any
#     123 """
#     124 if LogMode.get() == "disable":
# --> 125     return obj(*args, **kwargs)
#     127 logger = get_logger()
#     128 logger.log(log_level, start_line)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/pandas/series.py:404, in Series.__repr__(self)
#     402 num_rows = pandas.get_option("display.max_rows") or 60
#     403 num_cols = pandas.get_option("display.max_columns") or 20
# --> 404 temp_df = self._build_repr_df(num_rows, num_cols)
#     405 if isinstance(temp_df, pandas.DataFrame) and not temp_df.empty:
#     406     temp_df = temp_df.iloc[:, 0]
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/logging/logger_decorator.py:125, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     110 """
#     111 Compute function with logging if Modin logging is enabled.
#     112
#    (...)
#     122 Any
#     123 """
#     124 if LogMode.get() == "disable":
# --> 125     return obj(*args, **kwargs)
#     127 logger = get_logger()
#     128 logger.log(log_level, start_line)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/pandas/base.py:262, in BasePandasDataset._build_repr_df(self, num_rows, num_cols)
#     260 else:
#     261     indexer = row_indexer
# --> 262 return self.iloc[indexer]._query_compiler.to_pandas()
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/logging/logger_decorator.py:125, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     110 """
#     111 Compute function with logging if Modin logging is enabled.
#     112
#    (...)
#     122 Any
#     123 """
#     124 if LogMode.get() == "disable":
# --> 125     return obj(*args, **kwargs)
#     127 logger = get_logger()
#     128 logger.log(log_level, start_line)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/storage_formats/pandas/query_compiler.py:293, in PandasQueryCompiler.to_pandas(self)
#     292 def to_pandas(self):
# --> 293     return self._modin_frame.to_pandas()
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/logging/logger_decorator.py:125, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     110 """
#     111 Compute function with logging if Modin logging is enabled.
#     112
#    (...)
#     122 Any
#     123 """
#     124 if LogMode.get() == "disable":
# --> 125     return obj(*args, **kwargs)
#     127 logger = get_logger()
#     128 logger.log(log_level, start_line)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/utils.py:503, in lazy_metadata_decorator.<locals>.decorator.<locals>.run_f_on_minimally_updated_metadata(self, *args, **kwargs)
#     501     elif apply_axis == "rows":
#     502         obj._propagate_index_objs(axis=0)
# --> 503 result = f(self, *args, **kwargs)
#     504 if apply_axis is None and not transpose:
#     505     result._deferred_index = self._deferred_index
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:4465, in PandasDataframe.to_pandas(self)
#    4456 @lazy_metadata_decorator(apply_axis="both")
#    4457 def to_pandas(self):
#    4458     """
#    4459     Convert this Modin DataFrame to a pandas DataFrame.
#    4460
#    (...)
#    4463     pandas.DataFrame
#    4464     """
# -> 4465     df = self._partition_mgr_cls.to_pandas(self._partitions)
#    4466     if df.empty:
#    4467         df = pandas.DataFrame(columns=self.columns, index=self.index)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/logging/logger_decorator.py:125, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     110 """
#     111 Compute function with logging if Modin logging is enabled.
#     112
#    (...)
#     122 Any
#     123 """
#     124 if LogMode.get() == "disable":
# --> 125     return obj(*args, **kwargs)
#     127 logger = get_logger()
#     128 logger.log(log_level, start_line)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:801, in PandasDataframePartitionManager.to_pandas(cls, partitions)
#     786 @classmethod
#     787 def to_pandas(cls, partitions):
#     788     """
#     789     Convert NumPy array of PandasDataframePartition to pandas DataFrame.
#     790
#    (...)
#     799         A pandas DataFrame
#     800     """
# --> 801     retrieved_objects = cls.get_objects_from_partitions(partitions.flatten())
#     802     return create_pandas_df_from_partitions(retrieved_objects, partitions.shape)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/logging/logger_decorator.py:125, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     110 """
#     111 Compute function with logging if Modin logging is enabled.
#     112
#    (...)
#     122 Any
#     123 """
#     124 if LogMode.get() == "disable":
# --> 125     return obj(*args, **kwargs)
#     127 logger = get_logger()
#     128 logger.log(log_level, start_line)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:986, in PandasDataframePartitionManager.get_objects_from_partitions(cls, partitions)
#     982             partitions[idx] = part.force_materialization()
#     983     assert all(
#     984         [len(partition.list_of_blocks) == 1 for partition in partitions]
#     985     ), "Implementation assumes that each partition contains a single block."
# --> 986     return cls._execution_wrapper.materialize(
#     987         [partition.list_of_blocks[0] for partition in partitions]
#     988     )
#     989 return [partition.get() for partition in partitions]
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py:129, in RayWrapper.materialize(cls, obj_id)
#     126     return ray.get(obj_id) if isinstance(obj_id, RayObjectRefTypes) else obj_id
#     128 if all(isinstance(obj, RayObjectRefTypes) for obj in obj_id):
# --> 129     return ray.get(obj_id)
#     131 ids = {}
#     132 result = []
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/ray/_private/worker.py:2691, in get(object_refs, timeout)
#    2685     raise ValueError(
#    2686         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2687         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2688     )
#    2690 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2691 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2692 for i, value in enumerate(values):
#    2693     if isinstance(value, RayError):
#
# File ~/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/ray/_private/worker.py:871, in Worker.get_objects(self, object_refs, timeout, return_exceptions)
#     869     global_worker.core_worker.dump_object_store_memory_usage()
#     870 if isinstance(value, RayTaskError):
# --> 871     raise value.as_instanceof_cause()
#     872 else:
#     873     raise value
#
# RayTaskError(LookupError): ray::remote_exec_func() (pid=12833, ip=192.168.126.137)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RayTaskError: ray::_remote_exec_single_chain() (pid=12818, ip=192.168.126.137)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/execution/ray/common/deferred_execution.py", line 643, in construct
#     raise err
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/execution/ray/common/deferred_execution.py", line 633, in construct
#     obj = next(gen)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/execution/ray/common/deferred_execution.py", line 711, in construct_chain
#     obj = cls.exec_func(fn, obj, args, kwargs)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/execution/ray/common/deferred_execution.py", line 605, in exec_func
#     raise err
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/execution/ray/common/deferred_execution.py", line 592, in exec_func
#     return fn(obj, *args, **kwargs)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/core/dataframe/algebra/map.py", line 51, in <lambda>
#     lambda x: function(x, *args, **kwargs), *call_args, **call_kwds
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/frame.py", line 10468, in map
#     return self.apply(infer).__finalize__(self, "map")
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/frame.py", line 10374, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/apply.py", line 916, in apply
#     return self.apply_standard()
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/apply.py", line 1063, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/apply.py", line 1081, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/frame.py", line 10466, in infer
#     return x._map_values(func, na_action=na_action)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/base.py", line 921, in _map_values
#     return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/pandas/core/algorithms.py", line 1743, in map_array
#     return lib.map_infer(values, mapper, convert=convert)
#   File "lib.pyx", line 2972, in pandas._libs.lib.map_infer
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/modin/pandas/series.py", line 1268, in <lambda>
#     arg(s) if pandas.isnull(s) is not True or na_action is None else s
#   File "/tmp/ipykernel_12497/4137630162.py", line 20, in preccess
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/nltk/tokenize/__init__.py", line 142, in word_tokenize
#     sentences = [text] if preserve_line else sent_tokenize(text, language)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/nltk/tokenize/__init__.py", line 119, in sent_tokenize
#     tokenizer = _get_punkt_tokenizer(language)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/nltk/tokenize/__init__.py", line 105, in _get_punkt_tokenizer
#     return PunktTokenizer(language)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/nltk/tokenize/punkt.py", line 1744, in __init__
#     self.load_lang(lang)
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/nltk/tokenize/punkt.py", line 1749, in load_lang
#     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#   File "/home/lcda/miniconda3/envs/dl_with_pytorch/lib/python3.10/site-packages/nltk/data.py", line 579, in find
#     raise LookupError(resource_not_found)
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - '/home/lcda/nltk_data'
#     - '/home/lcda/miniconda3/envs/dl_with_pytorch/nltk_data'
#     - '/home/lcda/miniconda3/envs/dl_with_pytorch/share/nltk_data'
#     - '/home/lcda/miniconda3/envs/dl_with_pytorch/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# ### Exercise 4: Feature Generation (TF-IDF)
# **Objective**: Convert the preprocessed text data into numerical features using TF-IDF.
#
# 1. Use the `TfidfVectorizer` from `sklearn` to convert the reviews into numerical vectors.
# 2. Limit the maximum number of features to 5,000 to reduce the dimensionality.
# 3. Fit the vectorizer on the training set and transform both the training and test sets.
# 4. Print the shape of the transformed feature sets to confirm the conversion.

# %% [markdown]
# ### Exercise 5: Building the MLP Model (PyTorch)
# **Objective**: Build a simple Multi-Layer Perceptron (MLP) for binary classification.
#
# 1. Define the MLP model using `torch.nn.Module`. The model should have:
#     - An input layer that matches the size of the TF-IDF features.
#     - Two hidden layers with ReLU activations.
#     - A single output layer with a sigmoid activation function.
# 2. Print the model summary.

# %% [markdown]
# ### Exercise 6: Training the Model
# **Objective**: Train the MLP model on the training data.
#
# 1. Convert the TF-IDF feature matrices and labels into PyTorch tensors (the label needs to be binarized).
# 2. Define the loss function (`BCELoss` for binary classification) and the optimizer (`Adam`).
# 3. Implement a training loop to train the model for a specified number of epochs (e.g., 50).
# 4. Monitor the training and validation loss during training.

# %% [markdown]
# ### Exercise 7: Model Evaluation
# **Objective**: Evaluate the performance of the trained model on the test data.
#
# 1. Use the trained model to make predictions on the test set.
# 2. Calculate the accuracy of the model on the test data.
# 3. Print the test accuracy.

# %% [markdown]
# ### **Exercise 8: Saving the Trained Model**
#
# 1. Save the model's state_dict using `torch.save()`.
#
# 2. Save the entire model, including its architecture and weights.
#
# 3. Demonstrate how to load the saved model and use it for making predictions on new data.
